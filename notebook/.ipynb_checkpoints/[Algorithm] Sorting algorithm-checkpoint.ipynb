# %% [markdown]
# # Sorting Algorithm
# - Problem: Sort a random array in decending order.

# %%
import random
import time

ARR_SIZE = 4096

arr_rand = list(range(ARR_SIZE))
random.shuffle(arr_rand)

print(arr_rand)
# Out:
# [3168, 3123, 3554, 3381, 4080, 2650, 744, 157, 2444, 764, 3055, 3859, 2410, 319, 3414, 840, 1776, 212, 3454, 135, 855, 3509, 3187, 3013, 4084, 260, 483, 3711, 152, 1140, 3265, 3446, 360, 2989, 1107, 975, 2795, 1030, 1514, 1789, 1765, 404, 993, 1449, 3010, 2918, 2020, 4006, 308, 2210, 1551, 2582, 2016, 240, 26, 819, 1566, 48, 1362, 1144, 1197, 1357, 2898, 2327, 3899, 96, 1467, 715, 1686, 3565, 3557, 1159, 147, 3758, 64, 1797, 3186, 3827, 190, 2347, 2363, 1542, 194, 3675, 1714, 3751, 532, 1985, 3985, 1382, 1992, 1394, 330, 3252, 2851, 1751, 1272, 181, 2503, 591, 1783, 2038, 371, 3234, 512, 1725, 122, 2061, 875, 1539, 3100, 3270, 1785, 1819, 2385, 1893, 3846, 3779, 2033, 405, 2952, 290, 266, 3410, 3626, 1224, 781, 1961, 876, 843, 1102, 2021, 3349, 1400, 3135, 1676, 213, 3607, 2819, 2302, 1489, 1011, 3430, 1188, 2278, 1815, 4082, 3839, 3573, 1291, 2860, 3369, 3159, 716, 3141, 1669, 2998, 159, 402, 3820, 233, 3867, 3909, 2944, 2524, 1922, 3767, 2337, 2403, 680, 1847, 601, 3981, 3112, 3699
# ...

# %% [markdown]
# ## 1. Insertion Algorithm
#
# - O(n^2)

# %%
arr = arr_rand.copy()
timestamp = time.time()

for i in range(1, ARR_SIZE):
    val_cur = arr[i]
    j = i
    while j > 0:
        if val_cur > arr[j-1]:
            arr[j] = arr[j-1]
            j -= 1
        else:
            break
    idx_sorted = j
    arr[idx_sorted] = val_cur

arr_sorted = arr
print('Total time: ', time.time() - timestamp)
print('Sorted array', arr_sorted)
# Out:
# Total time:  1.4791901111602783
# ...

# %% [markdown]
# ## 2. Merge sort
# - Devide and conquer
# - O(nlogn)

# %%
INF = 987654321
idx_mid = lambda arr: len(arr) // 2

arr = arr_rand.copy()
timestamp = time.time()

def merge_sort(arr1, arr2):
    if len(arr1) > 1:
        arr1 = merge_sort(arr1[:idx_mid(arr1)], arr1[idx_mid(arr1):])

    if len(arr2) > 1:
        arr2 = merge_sort(arr2[:idx_mid(arr2)], arr2[idx_mid(arr2):])

    i = j = 0

    len_merged = len(arr1) + len(arr2)
    arr_new = [-1 for _ in range(len_merged)]
    
    arr1.append(-INF)
    arr2.append(-INF)

    for k in range(len_merged):
      
        if arr1[i] > arr2[j]:
            arr_new[k] = arr1[i]
            i = i+1
        else:
            arr_new[k] = arr2[j]
            j = j+1

    return arr_new

arr_sorted = merge_sort(arr[:idx_mid(arr)], arr[idx_mid(arr):])

print('Total time: ', time.time() - timestamp)
print('Sorted array', arr_sorted)
# Out:
# Total time:  0.017951250076293945
# ...

# %% [markdown]
# ## 3. Heap sort
#
# - O(nlogn)
# <img src="../asset/sorting_algorithm/fig1.jpg" alt="img" style="width: 600px;"/>
# <img src="../asset/sorting_algorithm/fig2.jpg" alt="img" style="width: 600px;"/>
# <img src="../asset/sorting_algorithm/fig3.jpg" alt="img" style="width: 600px;"/>
# <img src="../asset/sorting_algorithm/fig4.jpg" alt="img" style="width: 600px;"/>
# <img src="../asset/sorting_algorithm/fig5.jpg" alt="img" style="width: 600px;"/>
# <img src="../asset/sorting_algorithm/fig6_.jpg" alt="img" style="width: 600px;"/>
# <img src="../asset/sorting_algorithm/fig7.jpg" alt="img" style="width: 600px;"/>

# %%
arr = arr_rand.copy()
timestamp = time.time()

def exchange_element(arr, i, j):
    temp = arr[i]
    arr[i] = arr[j]
    arr[j] = temp

def min_heapify(arr, i, heap_size):
    child_l = 2*i
    child_r = 2*i + 1
    
    lower_idx = i
    
    if child_l < heap_size and arr[child_l] < arr[i]:
        lower_idx = child_l
        
    if child_r < heap_size and arr[child_r] < arr[lower_idx]:
        lower_idx = child_r
    
    if lower_idx != i:
        exchange_element(arr, lower_idx, i)
        min_heapify(arr, lower_idx, heap_size)
    
    
def build_min_heap(arr):
    last_parent = len(arr) // 2
    
    for i in reversed(range(last_parent)):
        min_heapify(arr, i, len(arr))
        
def heap_sort(arr):
    build_min_heap(arr)
    heap_size = len(arr)
    for i in reversed(range(len(arr))):
        exchange_element(arr, 0, i)
        heap_size -= 1
        min_heapify(arr, 0, heap_size)
        
    return arr
        
arr_sorted = heap_sort(arr)
print('Total time: ', time.time() - timestamp)
print('Sorted array', arr_sorted)
# Out:
# Total time:  0.025930166244506836
# ...

# %% [markdown]
# ## 4. Quicksort
#
# - Worst case: O(n^2)
# - Average case: O(nlogn)
#
# <img src="../asset/sorting_algorithm/fig8.jpg" alt="img" style="width: 600px;"/>
# <img src="../asset/sorting_algorithm/fig9.jpg" alt="img" style="width: 600px;"/>
# <img src="../asset/sorting_algorithm/fig10.jpg" alt="img" style="width: 600px;"/>
# <img src="../asset/sorting_algorithm/fig11.jpg" alt="img" style="width: 600px;"/>
# <img src="../asset/sorting_algorithm/fig12.jpg" alt="img" style="width: 600px;"/>

# %%
arr = arr_rand.copy()
timestamp = time.time()

def partition(arr, p, r):
    pivot = arr[r]
    i = p - 1
    
    for j in range(p, r):
        if arr[j] > pivot:
            i = i + 1
            exchange_element(arr, i, j)
            
    exchange_element(arr, i+1, r)
    q = i+1
    
    return q


def quicksort(arr, p, r):
    if p < r:
        pivot_rand = random.choice(list(range(p,r+1)))
        exchange_element(arr, pivot_rand, r)
        
        q = partition(arr, p, r)
        quicksort(arr, p, q-1)
        quicksort(arr, q+1, r)

    return arr
arr_sorted = quicksort(arr, 0, len(arr)-1)
print('Total time: ', time.time() - timestamp)
print('Sorted array', arr_sorted)
# Out:
# Total time:  0.025930404663085938
# ...
